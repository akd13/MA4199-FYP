# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from hmmlearn import hmm
import warnings
from constants import *
import math
import os
import random
import matplotlib.pyplot as plt
import dill
from functools import reduce

# %% [markdown]
# # Helper Methods

# %%
def generate_random_sample(X, size):
    '''
    Given a list X, 
    generate random samples of given size
    '''
    Z_temp = random.sample(list(X), size)
    
    #Concatenation
    Z = [Z_temp[0]]
    for val in Z_temp[1:]:
        Z = np.concatenate([Z,[val]])
    
    return Z

def convert_values_to_list(list_val):
    '''
    Given a list X = [1 2 3] , 
    return X = [[1],[2],[3]]
    '''
    X = []
    for i in list_val:
        X.append([i])
    return X

def conversion_list_of_list(X, DIMENSION):
    '''
    Given a list X with values in lists,
    X = [[ 3  2  2],[4 8 10]]
    Convert each value to a list
    Return list of lists, array of lengths of each sequence
    X = [[3] [2] [2] [4] [8] [10]]
    ''' 
    X_new = []
    length = len(X)
    for idx, val_list in enumerate(X):
        Y = []
        for val in val_list:
            Y.append([val])
        X_new.append(Y)

    #Concatenation
    Z = X_new[0]
    for val_list in X_new[1:]:
        Z = np.concatenate([Z,val_list])

    # assign array of lengths for HMM
    lengths = [DIMENSION]*length
    
    return Z,lengths

#Calculate likelihood for given sequence according to given HMMs and return HMM
def likelihood_sequence(sequence, HMM_array):
    '''
    Given list of K HMMs and sequence,
    determines likelihood of sequence under all HMM models
    Returns index of HMM which has max likelihood
    ''' 
    scores = []
    length = [len(sequence)]
    for i, HMM in enumerate(HMM_array):
        calculated_score = HMM.score(sequence, length)
        scores.append(calculated_score)
    idx = scores.index(max(scores))
    return idx

def HMM_model_stats(model):
    '''
    Details of HMM model
    ''' 
    print("*************************************")
    print("Transition matrix")
    print(model.transmat_)
    print("*************************************")
    print("Means and stds of each hidden state")
    for i in range(model.n_components):
        print("Hidden state {0}".format(i))
        print("mean = ", model.means_[i])
        print("std = ", [np.sqrt(model.covars_[i])])
        print()

def BIC(model,X,lengths):
    LogLikelihood = model.score(X,lengths)
    num_hidden_states = model.n_components
    # D counts transition matrix (emission estimated by PDF), means = num_hidden_states  
    # covariance matrix = num_hidden_states
    D = num_hidden_states**2-num_hidden_states + 2*num_hidden_states
    BIC = LogLikelihood - (D/2)*np.log(len(X))
    return BIC
    
def BIC_array(HMM_array,X_i):
    BIC_total = 0
    for i in range(len(X_i)):
        model = HMM_array[i]
        X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        BIC_total+= BIC(model,X,lengths)
    return BIC_total

def likelihood_array(HMM_array,X_i):
    likelihood_total = 0
    for i in range(len(X_i)):
        if(len(X_i[i])>=HMM_array[i].n_components):
            model = HMM_array[i]
            X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
            LogLikelihood = model.score(X,lengths)
            likelihood = LogLikelihood 
            likelihood_total+= likelihood
    return likelihood_total

def plot_BIC(list_k, BIC_score):
    fig = plt.subplot(111)
    plt.plot(list_k, BIC_score, marker='o')  
    plt.xlabel('Value of K')
    plt.ylabel('Objective')
    plt.title('BIC')
    plt.show() 

def print_stats(assignments,length):
    for i in range(length):
        if(i%100==0):
            print(assignments[i])

# %% [markdown]
# # Merge data

# %%
previous = 'RPKMOutput/GeneNames/RNASeq/geneTXCD_RPKMoutput_'
timepoints = ['ATCACG-s_6_1_genome.txt','TTAGGC-s_6_1_genome.txt',
             'CAGATC-s_6_1_genome.txt','GCCAAT-s_6_1_genome.txt',
             'CTTGTA-s_6_1_genome.txt'
            ]
dataframes = []
for idx,file in enumerate(timepoints):
    df = pd.read_csv(previous+file, sep="	", na_values=['-'])
    df = df.dropna(how='any')
    df = df[['AccNum', 'GeneName','cdReads',
       'cdRPKM']]
    df.rename(columns={'cdRPKM':'cdRPKM'+str(idx), 'cdReads':'cdReads'+str(idx)}, inplace=True)
    dataframes.append(df)

# %%
df_rnaseq = reduce(lambda left,right: pd.merge(left,right,on=['AccNum','GeneName']), dataframes)

# %%
df_rnaseq.head()

# %%
# df_rnaseq.to_csv('RPKMOutput/RNASeq.txt',sep=' ',index=False)

# %%
previous = 'RPKMOutput/GeneNames/RPF/geneTXCD_RPKMoutput_'
timepoints = ['ATCACG-s_7_1_genome.txt','TTAGGC-s_7_1_genome.txt',
             'CAGATC-s_7_1_genome.txt','GCCAAT-s_7_1_genome.txt',
             'CTTGTA-s_7_1_genome.txt'
            ]
dataframes = []
for idx,file in enumerate(timepoints):
    df = pd.read_csv(previous+file, sep="	", na_values=['-'])
    df = df.dropna(how='any')
    df = df[['AccNum', 'GeneName','cdReads',
       'cdRPKM']]
    df.rename(columns={'cdRPKM':'cdRPKM'+str(idx), 'cdReads':'cdReads'+str(idx)}, inplace=True)
    dataframes.append(df)
df_rpf = reduce(lambda left,right: pd.merge(left,right,on=['AccNum','GeneName']), dataframes)
df_rpf.head()

# %%
# df_rpf.to_csv('RPKMOutput/RPF.txt',sep=' ',index=False)

# %%
# df_rnaseq = df_rnaseq[['AccNum','GeneName', 'cdRPKM0', 'cdRPKM1',
#        'cdRPKM2', 'cdRPKM3', 'cdRPKM4']]
# df_rpf = df_rpf[['AccNum','GeneName', 'cdRPKM0', 'cdRPKM1',
#        'cdRPKM2', 'cdRPKM3', 'cdRPKM4']]
df_TE = reduce(lambda left,right: pd.merge(left,right,on=['AccNum','GeneName']), [df_rnaseq,df_rpf])
df_TE.head()

# %%
df_TE[['cdRPKM0_x']] = df_TE[['cdRPKM0_x']].div(df_TE['cdRPKM0_y'].values,axis=0)
df_TE[['cdRPKM1_x']] = df_TE[['cdRPKM1_x']].div(df_TE['cdRPKM1_y'].values,axis=0)
df_TE[['cdRPKM2_x']] = df_TE[['cdRPKM2_x']].div(df_TE['cdRPKM2_y'].values,axis=0)
df_TE[['cdRPKM3_x']] = df_TE[['cdRPKM3_x']].div(df_TE['cdRPKM3_y'].values,axis=0)
df_TE[['cdRPKM4_x']] = df_TE[['cdRPKM4_x']].div(df_TE['cdRPKM4_y'].values,axis=0)
for i in range(0,5):
    df_TE.rename(columns={'cdRPKM'+str(i)+'_x':'TE'+str(i)}, inplace=True)

# %%
df_TE.keys()

# %%
df_TE = df_TE[['AccNum', 'GeneName','TE0','TE1','TE2','TE3','TE4']]
df_TE.head()

# %%
# df_TE.to_csv('RPKMOutput/TE.txt',sep=' ',index=False)

# %% [markdown]
# # Load Data and Clean

# %%
df_rnaseq.keys()

# %%
#Dataset
df_rnaseq = pd.read_csv('RPKMOutput/RNASeq.txt',sep='\t')
df_rnaseq = df_rnaseq[(df_rnaseq['cdReads0'] >= 10) & (df_rnaseq['cdReads1'] >= 10) & (df_rnaseq['cdReads2'] >= 10)& (df_rnaseq['cdReads3'] >= 10)& (df_rnaseq['cdReads4'] >= 10)]
df_main = df_rnaseq[['cdRPKM0','cdRPKM1','cdRPKM2','cdRPKM3','cdRPKM4']]
LENGTH,DIMENSION = df_main.shape
print("Dataset size is",LENGTH)
print("Features are", DIMENSION)
print(df_main.head(5))
X = np.log2(df_main.values)
print("****************************")
print("First 5 log2 values\n",X[:5])
# Out:
# Dataset size is 10340
# Features are 5
#      cdRPKM0    cdRPKM1    cdRPKM2    cdRPKM3    cdRPKM4
# 0   6.642349   5.591876   6.004645   5.369988   8.507454
# 2   8.115351   9.879314   9.263817   7.164127   7.730539
# 3  54.937502  55.371390  64.913315  67.172940  78.293873
# 5  49.166094  35.735701  40.321640  35.461616  35.952554
# 8  35.030842  32.456656  35.944257  37.945878  41.572410
# ****************************
# First 5 log2 values
#  [[ 2.7316935   2.48333227  2.58607888  2.42491875  3.08872747]
#  [ 3.02065354  3.30441091  3.21160671  2.8407909   2.95056898]
#  [ 5.7797194   5.79106884  6.02044253  6.06980827  6.29082751]
#  [ 5.61959185  5.1592942   5.33348242  5.1481864   5.16802236]
#  [ 5.13055377  5.02044247  5.16768936  5.24587127  5.37755449]]

# %%
df_rnaseq.head(5)
# Out:
#          AccNum GeneName  cdReads0    cdRPKM0  cdReads1    cdRPKM1  cdReads2  \
# 0     NM_017847     ODR4      50.0   6.642349      62.0   5.591876      71.0
# 2  NM_001003803    ATP5S      29.0   8.115351      52.0   9.879314      52.0
# 3  NM_001003800    BICD2     778.0  54.937502    1155.0  55.371390    1444.0
# 5     NM_016647    THEM6     170.0  49.166094     182.0  35.735701     219.0
# 8     NM_016640   MRPS30     255.0  35.030842     348.0  32.456656     411.0
#
#      cdRPKM2  cdReads3    cdRPKM3  cdReads4    cdRPKM4
# 0   6.004645      30.0   5.369988      51.0   8.507454
# 2   9.263817      19.0   7.164127      22.0   7.730539
# 3  64.913315     706.0  67.172940     883.0  78.293873
# 5  40.321640      91.0  35.461616      99.0  35.952554
# 8  35.944257     205.0  37.945878     241.0  41.572410

# %% [markdown]
# # Arrays with HMM models for 1<=K<=25

# %%
HMM_K_ARRAYS = []
X_i_K_ARRAYS = []

# %% [markdown]
# # Check likelihood and do assignments

# %%
K_values = [13]

# %%
for K in K_values:
    HMM_array = []
    X_i = []
    print("**************** K =", K ,"************************")
    for i in range(K):
        X_i.append([])
        
    NUM_ITERATIONS = 0
    NUM_CLUSTER_PREV = {}
    NUM_CLUSTER_NOW = {}
    
    # Sequences for initial HMM estimation
    # Make K subsets data of LENGTH
    for i in range(LENGTH):
        for j in range(K):
            if(i%K==j):
                X_i[j].append(list(X[i]))
                NUM_CLUSTER_PREV[i] = j
                
    for i in range(K):
        model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
        X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        model.fit(X_temp, lengths)
        HMM_array.append(model)
    
    likelihood_prev = likelihood_array(HMM_array,X_i)
    print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_prev)
    NUM_ITERATIONS+=1
    while (True):
        # Assign all sequences to HMM models

        print("************ Check likelihood of sequence in HMM  *********")
        NUM_CLUSTER_NOW = {}
        for idx,x in enumerate(X):
            sequence = convert_values_to_list(x)
            hmm_index = likelihood_sequence(sequence, HMM_array)
            X_i[hmm_index].append(list(x))
            NUM_CLUSTER_NOW[idx] = hmm_index
        print("************ Checking likelihood done  *********")

        # Re-estimate parameters for new HMMs
        print("************ Re-estimating HMM *********")
        HMM_array_prev = HMM_array
        HMM_array = []
        for i in range(K):
            model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
            if(len(X_i[i])>=model.n_components):
                X_temp, lengths = conversion_list_of_list(X_i[i], DIMENSION)
                model.fit(X_temp, lengths)
                HMM_array.append(model)
            else:
                HMM_array.append(HMM_array_prev[i])
        print("************ Re-estimation done *********")
        likelihood_curr = likelihood_array(HMM_array,X_i)
        print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_curr)
        print("*****************************************")

        # if no reassignments, then break
        if ((NUM_CLUSTER_PREV == NUM_CLUSTER_NOW)):
            HMM_K_ARRAYS.append(HMM_array)
            X_i_K_ARRAYS.append(X_i)
            break
        else:
            # initialize empty subsets of data for next iteration
            X_i = []
            for i in range(K):
                X_i.append([])

            NUM_CLUSTER_PREV = NUM_CLUSTER_NOW
            print("Num iterations is:", NUM_ITERATIONS)
            NUM_ITERATIONS += 1
            likelihood_prev = likelihood_curr
    print("**********************************************************\n\n")
# Out:
# **************** K = 13 ************************
# Likelihood for iteration 0 is -72711.7024899
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -107468.454663
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -14311.4695003
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -10238.9926471
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -8991.75674646
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -8316.63285815
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -7879.30871222
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -7569.68108729
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -7353.52309485
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -7127.58395601
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -6965.6720273
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -6845.35725486
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -6769.33628676
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -6734.77244107
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -6673.16633745
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -6608.93721714
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is -6536.80235678
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is -6522.87700896
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is -6466.67729139
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is -6421.32789143
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is -6388.43289794
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is -6340.60067634
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is -6297.84650031
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is -6271.54068547
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is -6353.69359407
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is -6204.62883878
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is -6143.43425538
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is -6117.58895574
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is -6097.17524247
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is -6083.22635225
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is -6361.82276842
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is -6063.18533672
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is -6017.20287015
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is -6010.11633611
# *****************************************
# Num iterations is: 33
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 34 is -6005.67751558
# *****************************************
# Num iterations is: 34
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 35 is -6002.380359
# *****************************************
# Num iterations is: 35
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 36 is -6000.69745016
# *****************************************
# Num iterations is: 36
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 37 is -5997.10706199
# *****************************************
# Num iterations is: 37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 38 is -5990.86308475
# *****************************************
# Num iterations is: 38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 39 is -5985.97670304
# *****************************************
# Num iterations is: 39
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is -5977.04222215
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is -5972.58845104
# *****************************************
# Num iterations is: 41
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 42 is -5970.23066121
# *****************************************
# Num iterations is: 42
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 43 is -5969.601257
# *****************************************
# Num iterations is: 43
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 44 is -5947.41501887
# *****************************************
# Num iterations is: 44
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 45 is -5947.03126402
# *****************************************
# Num iterations is: 45
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 46 is -5945.10197901
# *****************************************
# Num iterations is: 46
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 47 is -5945.85679728
# *****************************************
# Num iterations is: 47
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 48 is -5950.20025548
# *****************************************
# Num iterations is: 48
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 49 is -5954.19412025
# *****************************************
# Num iterations is: 49
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 50 is -5955.97944714
# *****************************************
# Num iterations is: 50
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 51 is -5954.66741577
# *****************************************
# Num iterations is: 51
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 52 is -5955.9556037
# *****************************************
# Num iterations is: 52
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 53 is -5961.65241188
# *****************************************
# Num iterations is: 53
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 54 is -5961.01812006
# *****************************************
# Num iterations is: 54
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 55 is -5960.57588952
# *****************************************
# Num iterations is: 55
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 56 is -5961.5885464
# *****************************************
# Num iterations is: 56
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 57 is -5962.84461448
# *****************************************
# Num iterations is: 57
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 58 is -5962.29349419
# *****************************************
# Num iterations is: 58
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 59 is -5961.83913242
# *****************************************
# Num iterations is: 59
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 60 is -5952.80261832
# *****************************************
# Num iterations is: 60
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 61 is -5929.96383678
# *****************************************
# Num iterations is: 61
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 62 is -5902.67841408
# *****************************************
# Num iterations is: 62
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 63 is -5870.36125289
# *****************************************
# Num iterations is: 63
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 64 is -5862.33273214
# *****************************************
# Num iterations is: 64
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 65 is -5859.60195806
# *****************************************
# Num iterations is: 65
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 66 is -5855.94387214
# *****************************************
# Num iterations is: 66
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 67 is -5854.09667755
# *****************************************
# Num iterations is: 67
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 68 is -5851.94859229
# *****************************************
# Num iterations is: 68
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 69 is -5852.56436778
# *****************************************
# Num iterations is: 69
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 70 is -5853.8404435
# *****************************************
# Num iterations is: 70
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 71 is -5872.16139014
# *****************************************
# Num iterations is: 71
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 72 is -5852.02750959
# *****************************************
# Num iterations is: 72
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 73 is -5850.99934975
# *****************************************
# Num iterations is: 73
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 74 is -5851.01047302
# *****************************************
# Num iterations is: 74
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 75 is -5850.87060485
# *****************************************
# Num iterations is: 75
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 76 is -5851.25540422
# *****************************************
# Num iterations is: 76
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 77 is -5850.48775279
# *****************************************
# Num iterations is: 77
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 78 is -5850.63740636
# *****************************************
# Num iterations is: 78
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 79 is -5850.70952838
# *****************************************
# Num iterations is: 79
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 80 is -5850.48636622
# *****************************************
# Num iterations is: 80
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 81 is -5850.46360118
# *****************************************
# **********************************************************

# %%
print(len(HMM_K_ARRAYS))
print(len(X_i_K_ARRAYS))
# Out:
# 1
# 1

# %%
import seaborn as sns

def plot_cluster(X,count):
    fig = plt.subplot(111)
    axes = plt.gca()
    axes.set_ylim([0,15])
    var_plot_list = ['cdRPKM0','cdRPKM1','cdRPKM2','cdRPKM3','cdRPKM4']
    total=0
    for i in range(len(X)):
        fig.plot(var_plot_list, X[i])
        total+=1
    title = "HMM "+ str(count)+" : " + str(total) + " points "
    plt.title(title)
    plt.savefig('/Users/akankshitadash/Desktop/Gene Ontology/5points/RNASeq/Clusters/Cluster'+str(count)+'.png')
    plt.show()
    
def plot_heatmap(X,idx):
    plt.figure()
    sns.heatmap(X,vmin=0, vmax=10)
    plt.title('Heatmap'+str(idx))
    plt.savefig('/Users/akankshitadash/Desktop/Gene Ontology/5points/RNASeq/Heat Map/HeatMap'+str(idx+1)+'.png')
    plt.show()

# %%
for idx,X in enumerate(X_i_K_ARRAYS[0]):
    plot_cluster(X,idx+1)
for idx,X in enumerate(X_i_K_ARRAYS[0]):
    plot_heatmap(X,idx)

# %%
df = pd.read_csv('RPKMOutput/RNASeq.txt',sep=' ')
df = df[(df['cdReads0'] >= 10) & (df['cdReads1'] >= 10) & (df['cdReads2'] >= 10)& (df['cdReads3'] >= 10)& (df['cdReads4'] >= 10)]
df = df.dropna()
df = df[['AccNum','GeneName','cdReads0','cdReads1','cdReads2','cdRPKM0','cdRPKM1','cdRPKM2','cdRPKM3','cdRPKM4']]
df[['cdRPKM0','cdRPKM1','cdRPKM2','cdRPKM3','cdRPKM4']] = df[['cdRPKM0','cdRPKM1','cdRPKM2','cdRPKM3','cdRPKM4']].transform(lambda x: np.log2(x))
df.head(5)
# Out:
#          AccNum GeneName  cdReads0  cdReads1  cdReads2   cdRPKM0   cdRPKM1  \
# 0     NM_017847     ODR4      50.0      62.0      71.0  2.731694  2.483332
# 2  NM_001003803    ATP5S      29.0      52.0      52.0  3.020654  3.304411
# 3  NM_001003800    BICD2     778.0    1155.0    1444.0  5.779719  5.791069
# 5     NM_016647    THEM6     170.0     182.0     219.0  5.619592  5.159294
# 8     NM_016640   MRPS30     255.0     348.0     411.0  5.130554  5.020442
#
#     cdRPKM2   cdRPKM3   cdRPKM4
# 0  2.586079  2.424919  3.088727
# 2  3.211607  2.840791  2.950569
# 3  6.020443  6.069808  6.290828
# 5  5.333482  5.148186  5.168022
# 8  5.167689  5.245871  5.377554

# %%
for idx,x in enumerate(X_i_K_ARRAYS[0]):
    genes=[]
    acc_nums=[]
    for row in x:
        temp = (df.loc[(df['cdRPKM0'] == row[0])& (df['cdRPKM1']== row[1]) & (df['cdRPKM2']== row[2])])
        if(not temp.empty):
            genes.append(temp['GeneName'].values[0])
            acc_nums.append(temp['AccNum'].values[0])
    print(len(x),len(genes))
    with open('/Users/akankshitadash/Desktop/Gene Ontology/5points/RNASeq/Gene Names/Gene'+str(idx+1)+'.txt','w') as f:
        for gene in genes:
            f.write("%s\n" % gene)
    with open('/Users/akankshitadash/Desktop/Gene Ontology/5points/RNASeq/Gene Names/AccNum'+str(idx+1)+'.txt','w') as f:
        for acc_num in acc_nums:
            f.write("%s\n" % acc_num)
# Out:
# 750 750
# 937 937
# 1121 1121
# 853 853
# 1092 1092
# 607 607
# 863 863
# 961 961
# 563 563
# 632 632
# 582 582
# 663 663
# 716 716

# %%
dill.dump_session('../Weights/HMM_GaussianHMM_5points_RNASeq.db')
