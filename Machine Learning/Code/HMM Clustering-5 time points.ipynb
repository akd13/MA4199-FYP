# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from hmmlearn import hmm
import warnings
from constants import *
import math
import os
import random
import matplotlib.pyplot as plt
import dill
from functools import reduce

# %% [markdown]
# # Helper Methods

# %%
def generate_random_sample(X, size):
    '''
    Given a list X, 
    generate random samples of given size
    '''
    Z_temp = random.sample(list(X), size)
    
    #Concatenation
    Z = [Z_temp[0]]
    for val in Z_temp[1:]:
        Z = np.concatenate([Z,[val]])
    
    return Z

def convert_values_to_list(list_val):
    '''
    Given a list X = [1 2 3] , 
    return X = [[1],[2],[3]]
    '''
    X = []
    for i in list_val:
        X.append([i])
    return X

def conversion_list_of_list(X, DIMENSION):
    '''
    Given a list X with values in lists,
    X = [[ 3  2  2],[4 8 10]]
    Convert each value to a list
    Return list of lists, array of lengths of each sequence
    X = [[3] [2] [2] [4] [8] [10]]
    ''' 
    X_new = []
    length = len(X)
    for idx, val_list in enumerate(X):
        Y = []
        for val in val_list:
            Y.append([val])
        X_new.append(Y)

    #Concatenation
    Z = X_new[0]
    for val_list in X_new[1:]:
        Z = np.concatenate([Z,val_list])

    # assign array of lengths for HMM
    lengths = [DIMENSION]*length
    
    return Z,lengths

#Calculate likelihood for given sequence according to given HMMs and return HMM
def likelihood_sequence(sequence, HMM_array):
    '''
    Given list of K HMMs and sequence,
    determines likelihood of sequence under all HMM models
    Returns index of HMM which has max likelihood
    ''' 
    scores = []
    length = [len(sequence)]
    for i, HMM in enumerate(HMM_array):
        calculated_score = HMM.score(sequence, length)
        scores.append(calculated_score)
    idx = scores.index(max(scores))
    return idx

def HMM_model_stats(model):
    '''
    Details of HMM model
    ''' 
    print("*************************************")
    print("Transition matrix")
    print(model.transmat_)
    print("*************************************")
    print("Means and stds of each hidden state")
    for i in range(model.n_components):
        print("Hidden state {0}".format(i))
        print("mean = ", model.means_[i])
        print("std = ", [np.sqrt(model.covars_[i])])
        print()

def BIC(model,X,lengths):
    LogLikelihood = model.score(X,lengths)
    num_hidden_states = model.n_components
    # D counts transition matrix (emission estimated by PDF), means = num_hidden_states  
    # covariance matrix = num_hidden_states
    D = num_hidden_states**2 + 2*num_hidden_states
    BIC = LogLikelihood - (D/2)*np.log(len(X))
    return BIC
    
def BIC_array(HMM_array,X_i):
    BIC_total = 0
    for i in range(len(X_i)):
        model = HMM_array[i]
        X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        BIC_total+= BIC(model,X,lengths)
    return BIC_total

def likelihood_array(HMM_array,X_i):
    likelihood_total = 1
    for i in range(len(X_i)):
        if(len(X_i[i])>=HMM_array[i].n_components):
            model = HMM_array[i]
            X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
            LogLikelihood = model.score(X,lengths)
            likelihood = LogLikelihood 
            likelihood_total*= likelihood
    return likelihood_total

def plot_BIC(list_k, BIC_score):
    fig = plt.subplot(111)
    plt.plot(list_k, BIC_score, marker='o')  
    plt.xlabel('Value of K')
    plt.ylabel('Objective')
    plt.title('BIC')
    plt.show() 

def print_stats(assignments,length):
    for i in range(length):
        if(i%100==0):
            print(assignments[i])

# %% [markdown]
# # Merge data

# %%
previous = 'RPKMOutput/GeneNames/RNASeq/geneTXCD_RPKMoutput_'
timepoints = ['ATCACG-s_6_1_genome.txt','TTAGGC-s_6_1_genome.txt',
             'CAGATC-s_6_1_genome.txt','GCCAAT-s_6_1_genome.txt',
             'CTTGTA-s_6_1_genome.txt'
            ]
dataframes = []
for idx,file in enumerate(timepoints):
    df = pd.read_csv(previous+file, sep="	", na_values=['-'])
    df = df.dropna(how='any')
    df = df[['AccNum', 'GeneName','cdReads',
       'cdRPKM']]
    df.rename(columns={'cdRPKM':'cdRPKM'+str(idx), 'cdReads':'cdReads'+str(idx)}, inplace=True)
    dataframes.append(df)

# %%
df_rnaseq = reduce(lambda left,right: pd.merge(left,right,on=['AccNum','GeneName']), dataframes)

# %%
df_rnaseq.head()
# Out:
#          AccNum GeneName  cdReads0    cdRPKM0  cdReads1    cdRPKM1  cdReads2  \
# 0     NM_017847     ODR4      50.0   6.642349      62.0   5.591876      71.0
# 1  NM_001143986     TLE6       4.0   0.421957       6.0   0.429708       3.0
# 2  NM_001003803    ATP5S      29.0   8.115351      52.0   9.879314      52.0
# 3  NM_001003800    BICD2     778.0  54.937502    1155.0  55.371390    1444.0
# 4     NM_016649     ESF1      17.0   1.206070      26.0   1.252307      10.0
#
#      cdRPKM2  cdReads3    cdRPKM3  cdReads4    cdRPKM4
# 0   6.004645      30.0   5.369988      51.0   8.507454
# 1   0.201468       3.0   0.426413       3.0   0.397381
# 2   9.263817      19.0   7.164127      22.0   7.730539
# 3  64.913315     706.0  67.172940     883.0  78.293873
# 4   0.451649       9.0   0.860333      20.0   1.781686

# %%
# df_rnaseq.to_csv('RPKMOutput/RNASeq.txt',sep=' ',index=False)

# %%
previous = 'RPKMOutput/GeneNames/RPF/geneTXCD_RPKMoutput_'
timepoints = ['ATCACG-s_7_1_genome.txt','TTAGGC-s_7_1_genome.txt',
             'CAGATC-s_7_1_genome.txt','GCCAAT-s_7_1_genome.txt',
             'CTTGTA-s_7_1_genome.txt'
            ]
dataframes = []
for idx,file in enumerate(timepoints):
    df = pd.read_csv(previous+file, sep="	", na_values=['-'])
    df = df.dropna(how='any')
    df = df[['AccNum', 'GeneName','cdReads',
       'cdRPKM']]
    df.rename(columns={'cdRPKM':'cdRPKM'+str(idx), 'cdReads':'cdReads'+str(idx)}, inplace=True)
    dataframes.append(df)
df_rpf = reduce(lambda left,right: pd.merge(left,right,on=['AccNum','GeneName']), dataframes)
df_rpf.head()
# Out:
#          AccNum GeneName  cdReads0    cdRPKM0  cdReads1    cdRPKM1  cdReads2  \
# 0     NM_017847     ODR4      93.0  16.487335      62.0  13.206484      49.0
# 1  NM_001143986     TLE6       4.0   0.563098       2.0   0.338285       2.0
# 2  NM_001003803    ATP5S      81.0  30.248942      83.0  37.241851      71.0
# 3  NM_001003800    BICD2     501.0  47.210965     389.0  44.043594     284.0
# 4     NM_016649     ESF1      69.0   6.532635      52.0   5.915217      41.0
#
#      cdRPKM2  cdReads3    cdRPKM3  cdReads4    cdRPKM4
# 0  15.968568      37.0  16.540714      39.0  20.464235
# 1   0.517555       1.0   0.354984       1.0   0.416666
# 2  48.740039      46.0  43.317961      26.0  28.738355
# 3  49.195554     257.0  61.069347     230.0  64.149959
# 4   7.135519      26.0   6.207228      26.0   7.285780

# %%
# df_rpf.to_csv('RPKMOutput/RPF.txt',sep=' ',index=False)

# %%
# df_rnaseq = df_rnaseq[['AccNum','GeneName', 'cdRPKM0', 'cdRPKM1',
#        'cdRPKM2', 'cdRPKM3', 'cdRPKM4']]
# df_rpf = df_rpf[['AccNum','GeneName', 'cdRPKM0', 'cdRPKM1',
#        'cdRPKM2', 'cdRPKM3', 'cdRPKM4']]
df_TE = reduce(lambda left,right: pd.merge(left,right,on=['AccNum','GeneName']), [df_rnaseq,df_rpf])
df_TE.head()
# Out:
#          AccNum GeneName  cdReads0_x  cdRPKM0_x  cdReads1_x  cdRPKM1_x  \
# 0     NM_017847     ODR4        50.0   6.642349        62.0   5.591876
# 1  NM_001143986     TLE6         4.0   0.421957         6.0   0.429708
# 2  NM_001003803    ATP5S        29.0   8.115351        52.0   9.879314
# 3  NM_001003800    BICD2       778.0  54.937502      1155.0  55.371390
# 4     NM_016649     ESF1        17.0   1.206070        26.0   1.252307
#
#    cdReads2_x  cdRPKM2_x  cdReads3_x  cdRPKM3_x    ...      cdReads0_y  \
# 0        71.0   6.004645        30.0   5.369988    ...            93.0
# 1         3.0   0.201468         3.0   0.426413    ...             4.0
# 2        52.0   9.263817        19.0   7.164127    ...            81.0
# 3      1444.0  64.913315       706.0  67.172940    ...           501.0
# 4        10.0   0.451649         9.0   0.860333    ...            69.0
#
#    cdRPKM0_y  cdReads1_y  cdRPKM1_y  cdReads2_y  cdRPKM2_y  cdReads3_y  \
# 0  16.487335        62.0  13.206484        49.0  15.968568        37.0
# 1   0.563098         2.0   0.338285         2.0   0.517555         1.0
# 2  30.248942        83.0  37.241851        71.0  48.740039        46.0
# 3  47.210965       389.0  44.043594       284.0  49.195554       257.0
# 4   6.532635        52.0   5.915217        41.0   7.135519        26.0
#
#    cdRPKM3_y  cdReads4_y  cdRPKM4_y
# 0  16.540714        39.0  20.464235
# 1   0.354984         1.0   0.416666
# 2  43.317961        26.0  28.738355
# 3  61.069347       230.0  64.149959
# 4   6.207228        26.0   7.285780
#
# [5 rows x 22 columns]

# %%
df_TE[['cdRPKM0_x']] = df_TE[['cdRPKM0_x']].div(df_TE['cdRPKM0_y'].values,axis=0)
df_TE[['cdRPKM1_x']] = df_TE[['cdRPKM1_x']].div(df_TE['cdRPKM1_y'].values,axis=0)
df_TE[['cdRPKM2_x']] = df_TE[['cdRPKM2_x']].div(df_TE['cdRPKM2_y'].values,axis=0)
df_TE[['cdRPKM3_x']] = df_TE[['cdRPKM3_x']].div(df_TE['cdRPKM3_y'].values,axis=0)
df_TE[['cdRPKM4_x']] = df_TE[['cdRPKM4_x']].div(df_TE['cdRPKM4_y'].values,axis=0)
for i in range(0,5):
    df_TE.rename(columns={'cdRPKM'+str(i)+'_x':'TE'+str(i)}, inplace=True)

# %%
df_TE.keys()
# Out:
# Index(['AccNum', 'GeneName', 'cdReads0_x', 'TE0', 'cdReads1_x', 'TE1',
#        'cdReads2_x', 'TE2', 'cdReads3_x', 'TE3', 'cdReads4_x', 'TE4',
#        'cdReads0_y', 'cdRPKM0_y', 'cdReads1_y', 'cdRPKM1_y', 'cdReads2_y',
#        'cdRPKM2_y', 'cdReads3_y', 'cdRPKM3_y', 'cdReads4_y', 'cdRPKM4_y'],
#       dtype='object')

# %%
df_TE = df_TE[['AccNum', 'GeneName','TE0','TE1','TE2','TE3','TE4']]
df_TE.head()
# Out:
#          AccNum GeneName       TE0       TE1       TE2       TE3       TE4
# 0     NM_017847     ODR4  0.402876  0.423419  0.376029  0.324653  0.415723
# 1  NM_001143986     TLE6  0.749349  1.270257  0.389269  1.201215  0.953718
# 2  NM_001003803    ATP5S  0.268285  0.265275  0.190066  0.165385  0.268997
# 3  NM_001003800    BICD2  1.163660  1.257195  1.319496  1.099945  1.220482
# 4     NM_016649     ESF1  0.184622  0.211709  0.063296  0.138602  0.244543

# %%
# df_TE.to_csv('RPKMOutput/TE.txt',sep=' ',index=False)

# %% [markdown]
# # Load Data and Clean

# %%
df_rnaseq.keys()
# Out:
# Index(['AccNum', 'GeneName', 'cdReads0', 'cdRPKM0', 'cdReads1', 'cdRPKM1',
#        'cdReads2', 'cdRPKM2', 'cdReads3', 'cdRPKM3', 'cdReads4', 'cdRPKM4'],
#       dtype='object')

# %%
#Dataset
df_rnaseq = df_rnaseq[(df_rnaseq['cdReads0'] >= 50) & (df_rnaseq['cdReads1'] >= 50) & (df_rnaseq['cdReads2'] >= 50)& (df_rnaseq['cdReads3'] >= 50)& (df_rnaseq['cdReads4'] >= 50)]
df_main = df_rnaseq[['cdRPKM0','cdRPKM1','cdRPKM2','cdRPKM3','cdRPKM4']]
LENGTH,DIMENSION = df_main.shape
print("Dataset size is",LENGTH)
print("Features are", DIMENSION)
print(df_main.head(5))
X = np.log2(df_main.values)
print("****************************")
print("First 5 log2 values\n",X[:5])
# Out:
# Dataset size is 6830
# Features are 5
#       cdRPKM0    cdRPKM1    cdRPKM2    cdRPKM3    cdRPKM4
# 3   54.937502  55.371390  64.913315  67.172940  78.293873
# 5   49.166094  35.735701  40.321640  35.461616  35.952554
# 8   35.030842  32.456656  35.944257  37.945878  41.572410
# 12  24.639646  22.985487  17.653063  16.492664  19.366281
# 14  41.400942  41.318228  31.891348  33.470470  34.830747
# ****************************
# First 5 log2 values
#  [[ 5.7797194   5.79106884  6.02044253  6.06980827  6.29082751]
#  [ 5.61959185  5.1592942   5.33348242  5.1481864   5.16802236]
#  [ 5.13055377  5.02044247  5.16768936  5.24587127  5.37755449]
#  [ 4.62290962  4.52265131  4.14184663  4.04375252  4.27547504]
#  [ 5.37159168  5.36870648  4.99509317  5.06481692  5.1222895 ]]

# %% [markdown]
# # Arrays with HMM models for 1<=K<=25

# %%
HMM_K_ARRAYS = []
X_i_K_ARRAYS = []

# %% [markdown]
# # Check likelihood and do assignments

# %%
K_values = range(2,26)

# %%
for K in K_values:
    HMM_array = []
    X_i = []
    print("**************** K =", K ,"************************")
    for i in range(K):
        X_i.append([])
        
    NUM_ITERATIONS = 0
    NUM_CLUSTER_PREV = {}
    NUM_CLUSTER_NOW = {}
    
    # Sequences for initial HMM estimation
    # Make K subsets data of LENGTH
    for i in range(LENGTH):
        for j in range(K):
            if(i%K==j):
                X_i[j].append(list(X[i]))
                NUM_CLUSTER_PREV[i] = j
                
    for i in range(K):
        model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
        X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        model.fit(X_temp, lengths)
        HMM_array.append(model)
    
    likelihood_prev = likelihood_array(HMM_array,X_i)
    print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_prev)
    NUM_ITERATIONS+=1
    while (True):
        # Assign all sequences to HMM models

        print("************ Check likelihood of sequence in HMM  *********")
        NUM_CLUSTER_NOW = {}
        for idx,x in enumerate(X):
            sequence = convert_values_to_list(x)
            hmm_index = likelihood_sequence(sequence, HMM_array)
            X_i[hmm_index].append(list(x))
            NUM_CLUSTER_NOW[idx] = hmm_index
        print("************ Checking likelihood done  *********")

        # Re-estimate parameters for new HMMs
        print("************ Re-estimating HMM *********")
        HMM_array_prev = HMM_array
        HMM_array = []
        for i in range(K):
            model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
            if(len(X_i[i])>=model.n_components):
                X_temp, lengths = conversion_list_of_list(X_i[i], DIMENSION)
                model.fit(X_temp, lengths)
                HMM_array.append(model)
            else:
                HMM_array.append(HMM_array_prev[i])
        print("************ Re-estimation done *********")
        likelihood_curr = likelihood_array(HMM_array,X_i)
        print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_curr)
        print("*****************************************")

        # if no reassignments, then break
        if ((NUM_CLUSTER_PREV == NUM_CLUSTER_NOW) or NUM_ITERATIONS>40):
            HMM_K_ARRAYS.append(HMM_array)
            X_i_K_ARRAYS.append(X_i)
            break
        else:
            # initialize empty subsets of data for next iteration
            X_i = []
            for i in range(K):
                X_i.append([])

            NUM_CLUSTER_PREV = NUM_CLUSTER_NOW
            print("Num iterations is:", NUM_ITERATIONS)
            NUM_ITERATIONS += 1
            likelihood_prev = likelihood_curr
    print("**********************************************************\n\n")
# Out:
# **************** K = 2 ************************
# Likelihood for iteration 0 is 449291319.043
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 1366805366.85
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 139405870.878
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 137601213.814
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 137027673.973
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 136676391.859
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 136476408.57
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 136363309.146
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 136332341.117
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 136304252.066
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 136249093.036
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 136087066.411
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 135972245.835
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 135954255.172
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 135942374.202
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 135917647.954
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 135900994.651
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 135867873.203
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 135795125.272
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 135719244.005
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 135672028.196
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 135627883.473
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 135632760.557
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 135588547.03
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 135570711.748
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 135562513.273
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 135518555.453
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 135489379.554
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 135485655.502
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 135439043.128
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 135403444.188
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 135356938.666
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 135334619.378
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 135360287.243
# *****************************************
# Num iterations is: 33
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 34 is 135363289.218
# *****************************************
# Num iterations is: 34
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 35 is 135351448.248
# *****************************************
# Num iterations is: 35
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 36 is 135304784.741
# *****************************************
# Num iterations is: 36
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 37 is 135290399.325
# *****************************************
# Num iterations is: 37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 38 is 135296806.519
# *****************************************
# Num iterations is: 38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 39 is 135298883.559
# *****************************************
# Num iterations is: 39
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is 135291823.538
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is 135291823.538
# *****************************************
# **********************************************************
#
#
# **************** K = 3 ************************
# Likelihood for iteration 0 is -2.81608628008e+12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1.31915442468e+13
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -196459084216.0
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -116265764908.0
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -110748268003.0
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -108793503047.0
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -109020284968.0
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -109150803350.0
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -108843390305.0
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -109029584454.0
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -108973293945.0
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -108816904117.0
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -108645198329.0
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -108636623566.0
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -108597370476.0
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -108494516807.0
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is -108374437981.0
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is -108356826789.0
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is -108379074079.0
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is -108380186410.0
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is -108381453964.0
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is -108424624249.0
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is -108425632436.0
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is -108428193665.0
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is -108411570638.0
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is -108408552507.0
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is -108428117739.0
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is -108452040141.0
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is -108435836102.0
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is -108435836102.0
# *****************************************
# **********************************************************
#
#
# **************** K = 4 ************************
# Likelihood for iteration 0 is 1.25699171633e+16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 8.06695596399e+16
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 7.46951139287e+13
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 5.07600412045e+13
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 4.26797081976e+13
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 4.09713960726e+13
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 4.02389207443e+13
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 4.01519554693e+13
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 4.04283020715e+13
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 4.07090486754e+13
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 4.06478505804e+13
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 4.04392106297e+13
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 4.01368914192e+13
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 4.00265907666e+13
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 4.01481799263e+13
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 4.01252101026e+13
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 3.99158590793e+13
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 3.96374885632e+13
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 3.92485040458e+13
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 3.9256699776e+13
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 3.91747729551e+13
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 3.90775328661e+13
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 3.89629241288e+13
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 3.89645156127e+13
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 3.89248719526e+13
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 3.89680970148e+13
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 3.90178781614e+13
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 3.91575402804e+13
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 3.93379000117e+13
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 3.93040685497e+13
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 3.92347399927e+13
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 3.92487444932e+13
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 3.93012879595e+13
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 3.93862387436e+13
# *****************************************
# Num iterations is: 33
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 34 is 3.94350485091e+13
# *****************************************
# Num iterations is: 34
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 35 is 3.94548266336e+13
# *****************************************
# Num iterations is: 35
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 36 is 3.94707944461e+13
# *****************************************
# Num iterations is: 36
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 37 is 3.94900799162e+13
# *****************************************
# Num iterations is: 37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 38 is 3.95150981145e+13
# *****************************************
# Num iterations is: 38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 39 is 3.95607952644e+13
# *****************************************
# Num iterations is: 39
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is 3.95645985778e+13
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is 3.96139715662e+13
# *****************************************
# **********************************************************
#
#
# **************** K = 5 ************************
# Likelihood for iteration 0 is -4.35403255341e+19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -4.54555271493e+20
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -4.73434403595e+15
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -4.70816901699e+15
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -4.22926608295e+15
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -4.3847950206e+15
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -4.56710724534e+15
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -4.63959480012e+15
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -4.4454585215e+15
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -3.9606476143e+15
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -3.86911179237e+15
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -3.93332066854e+15
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -4.11235006614e+15
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -4.14326674172e+15
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -4.23272359854e+15
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -4.25505193196e+15
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is -4.22669254736e+15
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is -4.18861619131e+15
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is -4.13386847445e+15
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is -4.05544796954e+15
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is -3.93189157679e+15
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is -3.86703037409e+15
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is -3.8845503646e+15
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is -3.9499455736e+15
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is -4.07221832523e+15
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is -4.27682887781e+15
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is -4.43113869256e+15
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is -4.57408672395e+15
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is -4.79840383588e+15
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is -5.13960630331e+15
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is -5.44663006035e+15
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is -6.03183767189e+15
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is -7.42989331282e+15
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is -8.68107190582e+15
# *****************************************
# Num iterations is: 33
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 34 is -8.27273308229e+15
# *****************************************
# Num iterations is: 34
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 35 is -7.16571477552e+15
# *****************************************
# Num iterations is: 35
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 36 is -6.19713605398e+15
# *****************************************
# Num iterations is: 36
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 37 is -5.67480223064e+15
# *****************************************
# Num iterations is: 37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 38 is -5.10584851553e+15
# *****************************************
# Num iterations is: 38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 39 is -4.80486788443e+15
# *****************************************
# Num iterations is: 39
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is -4.4404789622e+15
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is -4.14047423274e+15
# *****************************************
# **********************************************************
#
#
# **************** K = 6 ************************
# Likelihood for iteration 0 is 1.21353991621e+23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 1.41527629611e+24
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 6.99161121567e+16
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 3.07664088052e+16
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -6.06173368675e+16
# *****************************************
# Num iterations is: 4
# ...
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is 2.56452647303e+47
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is 2.53486175313e+47
# *****************************************
# **********************************************************
#
#
# **************** K = 20 ************************
# Likelihood for iteration 0 is 2.56684931313e+66
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 2.67608693219e+68
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 8.46765428404e+40
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 9.7623896282e+42
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 8.41687093183e+44
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -2.45157885328e+46
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -3.65348065135e+47
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -7.2044866001e+48
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -7.28050560236e+48
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -1.81089024407e+47
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 1.73692607291e+48
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -9.84049643375e+47
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -5.56212959251e+48
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 9.42896685289e+48
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 1.44575382629e+48
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -1.65436198439e+49
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is -2.29209449393e+49
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 4.73437796251e+49
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 2.405744838e+50
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 7.09639507307e+50
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 1.28463802564e+51
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 1.65131109173e+51
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 1.78621645561e+51
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 1.45384075326e+51
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 1.19985874839e+51
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 6.44042691752e+50
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 3.42681487146e+50
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 1.4670679236e+50
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 9.70948481122e+49
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 9.6411931424e+49
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 8.06065892968e+49
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 7.03535227407e+49
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 5.47719709151e+49
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 5.50400344814e+49
# *****************************************
# Num iterations is: 33
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 34 is 5.35461437425e+49
# *****************************************
# Num iterations is: 34
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 35 is 5.90537046692e+49
# *****************************************
# Num iterations is: 35
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 36 is 5.84354766834e+49
# *****************************************
# Num iterations is: 36
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 37 is 5.66418634368e+49
# *****************************************
# Num iterations is: 37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 38 is 5.36101997256e+49
# *****************************************
# Num iterations is: 38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 39 is 5.57966278666e+49
# *****************************************
# Num iterations is: 39
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is 5.70633914787e+49
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is 6.29931227049e+49
# *****************************************
# **********************************************************
#
#
# **************** K = 21 ************************
# Likelihood for iteration 0 is -1.89703513419e+69
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1.59641225653e+71
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 8.96783491033e+37
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -5.92534215882e+43
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ------------------------------------------------------------
# KeyboardInterrupt          Traceback (most recent call last)
# <ipython-input-29-0eb3cdb68f2a> in <module>()
#      34         for idx,x in enumerate(X):
#      35             sequence = convert_values_to_list(x)
# ---> 36             hmm_index = likelihood_sequence(sequence, HMM_array)
#      37             X_i[hmm_index].append(list(x))
#      38             NUM_CLUSTER_NOW[idx] = hmm_index
#
# <ipython-input-2-d7d0c43316f5> in likelihood_sequence(sequence, HMM_array)
#      59     length = [len(sequence)]
#      60     for i, HMM in enumerate(HMM_array):
# ---> 61         calculated_score = HMM.score(sequence, length)
#      62         scores.append(calculated_score)
#      63     idx = scores.index(max(scores))
#
# /usr/local/lib/python3.6/site-packages/hmmlearn/base.py in score(self, X, lengths)
#     243         self._check()
#     244
# --> 245         X = check_array(X)
#     246         # XXX we can unroll forward pass for speed and memory efficiency.
#     247         logprob = 0
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     453             _assert_all_finite(array)
#     454
# --> 455     shape_repr = _shape_repr(array.shape)
#     456     if ensure_min_samples > 0:
#     457         n_samples = _num_samples(array)
#
# /usr/local/lib/python3.6/site-packages/sklearn/utils/validation.py in _shape_repr(shape)
#     148     '()'
#     149     """
# --> 150     if len(shape) == 0:
#     151         return "()"
#     152     joined = ", ".join("%d" % e for e in shape)
#
# KeyboardInterrupt:

# %%
print(len(HMM_K_ARRAYS))
print(len(X_i_K_ARRAYS))
# Out:
# 19
# 19

# %%
dill.dump_session('../Weights/HMM_GaussianHMM_5points_log2_RNASeq.db')

# %% [markdown]
# # Calculate BIC for these assignments

# %%
print(BIC_array(HMM_array,X_i))

# %%
print(BIC_array(HMM_array,X_i))

# %% [markdown]
# # Noise Cluster

# %%
# Get list of lists to fit
Z, lengths = conversion_list_of_list(X,DIMENSION)

# %%
# Noise cluster 

model_noise = hmm.GMMHMM(n_components=3,n_mix=3,covariance_type='spherical')
model_noise.fit(Z, lengths)

# %%
HMM_model_stats(model_noise)

# %% [markdown]
# # Generate subsets of data for K HMMs

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))

# %%
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='full')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)

# %% [markdown]
# ## Statistics for K HMMs

# %%
HMM_model_stats(model)
print('\n\n')
model.predict([[7.56030946],[5.96591207],[6.40121497]],lengths=[3])
# Out:
# *************************************
# Transition matrix
# [[  9.99276869e-01   6.38482140e-04   8.46487741e-05]
#  [  1.93144205e-04   9.99806856e-01   2.07287602e-13]
#  [  1.68090394e-02   2.12582122e-11   9.83190961e-01]]
# *************************************
# Means and stds of each hidden state
# Hidden state 0
# mean =  [ 5.85591189]
# std =  [array([[ 0.49587845]])]
#
# Hidden state 1
# mean =  [ 7.75447354]
# std =  [array([[ 1.05975496]])]
#
# Hidden state 2
# mean =  [ 4.32879483]
# std =  [array([[ 0.68723547]])]
# array([1, 1, 1])

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='diag')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)
    HMM_array.append(model)
for i in range(K):
    print("Statistics for HMM Model", i)
    HMM_model_stats(HMM_array[i])
    print('\n\n')

# %%
NUM_ITERATIONS = 1
NUM_CLUSTER_PREV = {}
NUM_CLUSTER_NOW = {}

# %%
#initialize empty subsets of data
X_i = []

for i in range(K):
    X_i.append([])

# %%
likelihood_prev = likelihood_array(HMM_array,X_i)
print("Likelihood for iteration",0,"is",likelihood_prev)
