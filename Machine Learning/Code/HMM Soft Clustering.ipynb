# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from hmmlearn import hmm
import warnings
from constants import *
import math
import random
import matplotlib.pyplot as plt
import dill

# %% [markdown]
# # Helper Methods

# %%
def generate_random_sample(X, size):
    '''
    Given a list X, 
    generate random samples of given size
    '''
    Z_temp = random.sample(list(X), size)
    
    #Concatenation
    Z = [Z_temp[0]]
    for val in Z_temp[1:]:
        Z = np.concatenate([Z,[val]])
    
    return Z

def convert_values_to_list(list_val):
    '''
    Given a list X = [1 2 3] , 
    return X = [[1],[2],[3]]
    '''
    X = []
    for i in list_val:
        X.append([i])
    return X

def conversion_list_of_list(X, DIMENSION):
    '''
    Given a list X with values in lists,
    X = [[ 3  2  2],[4 8 10]]
    Convert each value to a list
    Return list of lists, array of lengths of each sequence
    X = [[3] [2] [2] [4] [8] [10]]
    ''' 
    X_new = []
    length = len(X)
    for idx, val_list in enumerate(X):
        Y = []
        for val in val_list:
            Y.append([val])
        X_new.append(Y)

    #Concatenation
    Z = X_new[0]
    for val_list in X_new[1:]:
        Z = np.concatenate([Z,val_list])

    # assign array of lengths for HMM
    lengths = [DIMENSION]*length
    
    return Z,lengths

def HMM_model_stats(model):
    '''
    Details of HMM model
    ''' 
    print("*************************************")
    print("Transition matrix")
    print(model.transmat_)
    print("*************************************")
    print("Means and stds of each hidden state")
    for i in range(model.n_components):
        print("Hidden state {0}".format(i))
        print("mean = ", model.means_[i])
        print("std = ", [np.sqrt(model.covars_[i])])
        print()

def BIC(HMM,X,lengths):
    LogLikelihood = model.score(X,lengths)
    num_hidden_states = model.n_components
    # D counts transition matrix (emission estimated by PDF), means = num_hidden_states  
    # covariance matrix = num_hidden_states
    D = num_hidden_states**2 + 2*num_hidden_states
    BIC = LogLikelihood - (D/2)*np.log(len(X))
    return BIC
    
def BIC_array(HMM_array,X_i):
    BIC_total = 0
    for i in range(len(X_i)):
        model = HMM_array[i]
        X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        BIC_total+= BIC(model,X,lengths)
    return BIC_total

#Calculate likelihood for given sequence according to given HMMs and return HMM
def likelihood_sequence_scores(sequence, HMM_array):
    '''
    Given list of K HMMs and sequence
    Returns index of max probability and normalized probabilities of each sequence
    ''' 
    scores = []
    length = [len(sequence)]
    for i, HMM in enumerate(HMM_array):
        calculated_score = math.exp(HMM.score(sequence, length))
        scores.append(calculated_score)
    idx = scores.index(max(scores))
    scores = [float(i)/sum(scores) for i in scores]
    return idx,scores

#Likelihood of K HMMs and X
def likelihood(HMM_array,X, scores):
    likelihood_total = 0
    for i in range(len(HMM_array)):
        model = HMM_array[i]
        for j in range(len(X)):
            sequence = convert_values_to_list(X[j])
            length = [len(sequence)]
            probability = scores[j][i] 
            likelihood_total+= probability*model.score(sequence, length)
    return likelihood_total

def plot_BIC(list_k, BIC_score):
    fig = plt.subplot(111)
    plt.plot(list_k, BIC_score, marker='o')  
    plt.xlabel('Value of K')
    plt.ylabel('Objective')
    plt.title('BIC')
    plt.show() 

def print_stats(assignments,length):
    for i in range(length):
        if(i%100==0):
            print(assignments[i])

# %% [markdown]
# # Load Data and Clean

# %%
df = pd.read_csv('../Data/merged.txt', sep=",", na_values=['-'])
df = df.dropna()
df = df[['cdReads0','cdReads1','cdReads2','cdRPKM0','cdRPKM1','cdRPKM2']]

# %% [markdown]
# # Filter cdReads

# %%
df = df[(df['cdReads0'] >= 150) & (df['cdReads1'] >= 150) & (df['cdReads2'] >= 150)]

# %%
#Dataset
df_main = df[['cdRPKM0','cdRPKM1','cdRPKM2']]
LENGTH,DIMENSION = df_main.shape
print("Dataset size is",LENGTH)
print("Features are", DIMENSION)
print(df_main.head(5))
X = np.log2(df_main.values)
print("****************************")
print("First 5 log2 values\n",X[:5])
# Out:
# Dataset size is 428
# Features are 3
#         cdRPKM0     cdRPKM1     cdRPKM2
# 19    29.836928   22.172994   17.721150
# 34   188.746942  211.104962  221.175677
# 162  167.985929  155.020762  208.252208
# 208   48.606530  102.089004   98.175834
# 217   68.062546   49.380837   53.007509
# ****************************
# First 5 log2 values
#  [[ 4.89902709  4.47073168  4.14740034]
#  [ 7.56030946  7.72181668  7.78904893]
#  [ 7.39219659  7.27631764  7.70218798]
#  [ 5.60307823  6.67368367  6.61729605]
#  [ 6.0887892   5.62587938  5.72812484]]

# %% [markdown]
# # Arrays with HMM models for 1<=K<=25

# %%
HMM_K_ARRAYS = []
X_i_K_ARRAYS = []

# %% [markdown]
# # Check likelihood and do assignments

# %% [markdown]
# I'm already doing the E-step right now, where I do hard assignment by choosing the sequence for which the probability is the maximum. I just need to generate the list of prior probabilities z_k where \sum(z_k)=1. This can be done by taking all the probabilities generated for each HMM and normalizing them. The i^th element in this list z_k represents the probability of being generated by the i^th model, and I will modify the objective likelihood function to be multiplied with this prior probability.

# %%
K_values = range(3,31)

# %%
for K in K_values:
    HMM_array = []
    X_i = []
    print("**************** K =", K ,"************************")
    for i in range(K):
        X_i.append([])
        
    NUM_ITERATIONS = 0
    NUM_CLUSTER_PREV = {}
    NUM_CLUSTER_NOW = {}
    NUM_SCORES = {}
    
    # Sequences for initial HMM estimation
    # Make K subsets data of LENGTH
    for i in range(LENGTH):
        for j in range(K):
            if(i%K==j):
                X_i[j].append(list(X[i]))
                NUM_CLUSTER_PREV[i] = j

    for i in range(K):
        model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
        X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        model.fit(X_temp, lengths)
        HMM_array.append(model)
    
    likelihood_prev = 0
    print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_prev)
    NUM_ITERATIONS+=1
    while (True):
        
        # E Step: Assign all sequences to HMM models
        print("************ Check likelihood of sequence in HMM  *********")
        NUM_CLUSTER_NOW = {}
        for idx,x in enumerate(X):
            sequence = convert_values_to_list(x)
            hmm_index, probability_scores = likelihood_sequence_scores(sequence, HMM_array)
            NUM_SCORES[idx] = probability_scores
            X_i[hmm_index].append(list(x))
            NUM_CLUSTER_NOW[idx] = hmm_index
        print("************ Checking likelihood done  *********")

        # M Step: Re-estimate parameters for new HMMs
        print("************ Re-estimating HMM *********")
        HMM_array_prev = HMM_array
        HMM_array = []
        for i in range(K):
            model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
            if(len(X_i[i])>=model.n_components):
                X_temp, lengths = conversion_list_of_list(X_i[i], DIMENSION)
                model.fit(X_temp, lengths)
                HMM_array.append(model)
            else:
                HMM_array.append(HMM_array_prev[i])
        print("************ Re-estimation done *********")
        likelihood_curr = likelihood(HMM_array,X,NUM_SCORES)
        print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_curr)
        print("*****************************************")

        # Stop: If no reassignments, then break
        if ((NUM_CLUSTER_PREV == NUM_CLUSTER_NOW) or NUM_ITERATIONS>40):
            HMM_K_ARRAYS.append(HMM_array)
            X_i_K_ARRAYS.append(X_i)
            break
        else:
            # initialize empty subsets of data for next iteration
            X_i = []
            for i in range(K):
                X_i.append([])

            NUM_CLUSTER_PREV = NUM_CLUSTER_NOW
            print("Num iterations is:", NUM_ITERATIONS)
            NUM_ITERATIONS += 1
            likelihood_prev = likelihood_curr
    print("**********************************************************\n\n")
# Out:
# **************** K = 3 ************************
# Likelihood for iteration 0 is 0
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1648.79527825
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -1481.245285
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -999.33798445
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -982.380840012
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -976.358372337
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -974.331475941
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -972.108444322
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -969.982803402
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -968.940561565
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -967.648817564
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -966.563511717
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -967.024398635
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -964.839060049
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -964.927912103
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -964.520200297
# *****************************************
# **********************************************************
#
#
# **************** K = 4 ************************
# Likelihood for iteration 0 is 0
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1567.5147386
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -2898.58921017
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -810.356744658
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -793.661897671
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -792.395209209
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -791.274483854
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -790.358610097
# *****************************************
# **********************************************************
#
#
# **************** K = 5 ************************
# Likelihood for iteration 0 is 0
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1522.85882742
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -2302.36089091
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -787.160811499
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -766.196487546
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -755.229026028
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -754.258329779
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -749.946158619
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -732.762317995
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -724.055344597
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -697.272731868
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -679.783621694
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -674.304160603
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -672.511772145
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -668.21312639
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -664.471282959
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is -662.936721568
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is -662.923660345
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is -662.975560579
# *****************************************
# **********************************************************
#
#
# **************** K = 6 ************************
# Likelihood for iteration 0 is 0
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1550.36852343
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -5195.16988708
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -2445.41796197
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -610.921223015
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -594.700417609
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -583.45842279
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -578.676330559
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -567.813075723
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -597.857666651
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -603.13405136
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -587.014909465
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -580.872824143
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -575.965549168
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -574.866686944
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -571.383361477
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is -571.058889037
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is -569.73028496
# *****************************************
# **********************************************************
#
#
# **************** K = 7 ************************
# Likelihood for iteration 0 is 0
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1531.88125141
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -4053.71911521
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -761.191456413
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -551.616405406
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -546.38240974
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -530.00510993
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -516.492605876
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -506.117221449
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -504.806558831
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -503.197855082
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -503.152467621
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -503.067179293
# *****************************************
# **********************************************************
#
#
# **************** K = 8 ************************
# Likelihood for iteration 0 is 0
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -1444.8231509
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -4169.98978925
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -653.36506413
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -634.114516773
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -546.143870467
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -629.622190798
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -593.582053071
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -519.60037175
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -520.893631649
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -521.440075955
# *****************************************
# **********************************************************
#
#
# **************** K = 9 ************************
# Likelihood for iteration 0 is 0
# ************ Check likelihood of sequence in HMM  *********
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-bc0acec1de5b> in <module>()
#      35         for idx,x in enumerate(X):
#      36             sequence = convert_values_to_list(x)
# ---> 37             hmm_index, probability_scores = likelihood_sequence_scores(sequence, HMM_array)
#      38             NUM_SCORES[idx] = probability_scores
#      39             X_i[hmm_index].append(list(x))
#
# <ipython-input-2-04c42f41a760> in likelihood_sequence_scores(sequence, HMM_array)
#      90     length = [len(sequence)]
#      91     for i, HMM in enumerate(HMM_array):
# ---> 92         calculated_score = math.exp(HMM.score(sequence, length))
#      93         scores.append(calculated_score)
#      94     idx = scores.index(max(scores))
#
# /usr/local/lib/python3.6/site-packages/hmmlearn/base.py in score(self, X, lengths)
#     241         """
#     242         check_is_fitted(self, "startprob_")
# --> 243         self._check()
#     244
#     245         X = check_array(X)
#
# /usr/local/lib/python3.6/site-packages/hmmlearn/hmm.py in _check(self)
#     179
#     180         _utils._validate_covars(self._covars_, self.covariance_type,
# --> 181                                 self.n_components)
#     182
#     183     def _init(self, X, lengths=None):
#
# /usr/local/lib/python3.6/site-packages/hmmlearn/_utils.py in _validate_covars(covars, covariance_type, n_components)
#       7 def _validate_covars(covars, covariance_type, n_components):
#       8     """Do basic checks on matrix covariance sizes and values."""
# ----> 9     from scipy import linalg
#      10     if covariance_type == 'spherical':
#      11         if len(covars) != n_components:
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
print(len(X_temp),lengths)
print(NUM_CLUSTER_NOW)
model.fit(X_temp)

# %%
dill.dump_session('../Weights/HMM_GaussianHMM_soft.db')

# %% [markdown]
# # Calculate BIC for these assignments

# %%
print(BIC_array(HMM_array,X_i))

# %%
print(BIC_array(HMM_array,X_i))

# %% [markdown]
# # Noise Cluster

# %%
# Get list of lists to fit
Z, lengths = conversion_list_of_list(X,DIMENSION)

# %%
# Noise cluster 

model_noise = hmm.GMMHMM(n_components=3,n_mix=3,covariance_type='spherical')
model_noise.fit(Z, lengths)

# %%
HMM_model_stats(model_noise)

# %% [markdown]
# # Generate subsets of data for K HMMs

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))

# %%
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='full')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)

# %% [markdown]
# ## Statistics for K HMMs

# %%
HMM_model_stats(model)
print('\n\n')
model.predict([[7.56030946],[5.96591207],[6.40121497]],lengths=[3])

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='diag')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)
    HMM_array.append(model)
for i in range(K):
    print("Statistics for HMM Model", i)
    HMM_model_stats(HMM_array[i])
    print('\n\n')

# %%
NUM_ITERATIONS = 1
NUM_CLUSTER_PREV = {}
NUM_CLUSTER_NOW = {}

# %%
#initialize empty subsets of data
X_i = []

for i in range(K):
    X_i.append([])

# %%
likelihood_prev = likelihood_array(HMM_array,X_i)
print("Likelihood for iteration",0,"is",likelihood_prev)
