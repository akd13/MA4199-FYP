# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from hmmlearn import hmm
import warnings
from constants import *
import math
import random
import matplotlib.pyplot as plt
import dill

# %% [markdown]
# # Helper Methods

# %%
def generate_random_sample(X, size):
    '''
    Given a list X, 
    generate random samples of given size
    '''
    Z_temp = random.sample(list(X), size)
    
    #Concatenation
    Z = [Z_temp[0]]
    for val in Z_temp[1:]:
        Z = np.concatenate([Z,[val]])
    
    return Z

def convert_values_to_list(list_val):
    '''
    Given a list X = [1 2 3] , 
    return X = [[1],[2],[3]]
    '''
    X = []
    for i in list_val:
        X.append([i])
    return X

def conversion_list_of_list(X, DIMENSION):
    '''
    Given a list X with values in lists,
    X = [[ 3  2  2],[4 8 10]]
    Convert each value to a list
    Return list of lists, array of lengths of each sequence
    X = [[3] [2] [2] [4] [8] [10]]
    ''' 
    X_new = []
    length = len(X)
    for idx, val_list in enumerate(X):
        Y = []
        for val in val_list:
            Y.append([val])
        X_new.append(Y)

    #Concatenation
    Z = X_new[0]
    for val_list in X_new[1:]:
        Z = np.concatenate([Z,val_list])

    # assign array of lengths for HMM
    lengths = [DIMENSION]*length
    
    return Z,lengths

#Calculate likelihood for given sequence according to given HMMs and return HMM
def likelihood_sequence(sequence, HMM_array):
    '''
    Given list of K HMMs and sequence,
    determines likelihood of sequence under all HMM models
    Returns index of HMM which has max likelihood
    ''' 
    scores = []
    length = [len(sequence)]
    for i, HMM in enumerate(HMM_array):
        calculated_score = HMM.score(sequence, length)
        scores.append(calculated_score)
    idx = scores.index(max(scores))
    return idx

def HMM_model_stats(model):
    '''
    Details of HMM model
    ''' 
    print("*************************************")
    print("Transition matrix")
    print(model.transmat_)
    print("*************************************")
    print("Means and stds of each hidden state")
    for i in range(model.n_components):
        print("Hidden state {0}".format(i))
        print("mean = ", model.means_[i])
        print("std = ", [np.sqrt(model.covars_[i])])
        print()

def BIC(model,X,lengths):
    LogLikelihood = model.score(X,lengths)
    num_hidden_states = model.n_components
    # D counts transition matrix (emission estimated by PDF), means = num_hidden_states  
    # covariance matrix = num_hidden_states
    D = num_hidden_states**2 + 2*num_hidden_states
    BIC = LogLikelihood - (D/2)*np.log(len(X))
    return BIC
    
def BIC_array(HMM_array,X_i):
    BIC_total = 0
    for i in range(len(X_i)):
        model = HMM_array[i]
        X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        BIC_total+= BIC(model,X,lengths)
    return BIC_total

def likelihood_array(HMM_array,X_i):
    likelihood_total = 1
    for i in range(len(X_i)):
        if(len(X_i[i])>=HMM_array[i].n_components):
            model = HMM_array[i]
            X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
            LogLikelihood = model.score(X,lengths)
            likelihood = LogLikelihood 
            likelihood_total*= likelihood
    return likelihood_total

def plot_BIC(list_k, BIC_score):
    fig = plt.subplot(111)
    plt.plot(list_k, BIC_score, marker='o')  
    plt.xlabel('Value of K')
    plt.ylabel('Objective')
    plt.title('BIC')
    plt.show() 

def print_stats(assignments,length):
    for i in range(length):
        if(i%100==0):
            print(assignments[i])

# %% [markdown]
# # Load Data and Clean

# %%
df = pd.read_csv('../Data/merged.txt', sep=",", na_values=['-'])
df = df.dropna()
df = df[['AccNum','GeneName','cdReads0','cdReads1','cdReads2','cdRPKM0','cdRPKM1','cdRPKM2']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b294ae2032c7> in <module>()
# ----> 1 df = pd.read_csv('../Data/merged.txt', sep=",", na_values=['-'])
#       2 df = df.dropna()
#       3 df = df[['AccNum','GeneName','cdReads0','cdReads1','cdReads2','cdRPKM0','cdRPKM1','cdRPKM2']]
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # Filter cdReads

# %%
df = df[(df['cdReads0'] >= 100) & (df['cdReads1'] >= 100) & (df['cdReads2'] >= 100)]

# %%
#Dataset
df_main = df[['cdRPKM0','cdRPKM1','cdRPKM2']]
LENGTH,DIMENSION = df_main.shape
print("Dataset size is",LENGTH)
print("Features are", DIMENSION)
print(df_main.head(5))
X = np.log2(df_main.values)
print("****************************")
print("First 5 log2 values\n",X[:5])
# Out:
# Dataset size is 817
# Features are 3
#        cdRPKM0     cdRPKM1     cdRPKM2
# 6    39.456786   62.505536   84.519655
# 19   29.836928   22.172994   17.721150
# 34  188.746942  211.104962  221.175677
# 57  283.823604  374.683044  285.247754
# 81   90.967704  125.648541  120.892583
# ****************************
# First 5 log2 values
#  [[ 5.30220154  5.96591207  6.40121497]
#  [ 4.89902709  4.47073168  4.14740034]
#  [ 7.56030946  7.72181668  7.78904893]
#  [ 8.14885076  8.54952688  8.15607171]
#  [ 6.50728253  6.97325011  6.91758192]]

# %%
for i in range(LENGTH):
    first_val = X[i][0]
    X[i][0]=0
    X[i][1]-=first_val
    X[i][2]-=first_val

# %% [markdown]
# # Arrays with HMM models for 1<=K<=25

# %%
HMM_K_ARRAYS = []
X_i_K_ARRAYS = []

# %% [markdown]
# # Check likelihood and do assignments

# %%
K_values = range(2,21)

# %%
for K in K_values:
    HMM_array = []
    X_i = []
    print("**************** K =", K ,"************************")
    for i in range(K):
        X_i.append([])
        
    NUM_ITERATIONS = 0
    NUM_CLUSTER_PREV = {}
    NUM_CLUSTER_NOW = {}
    
    # Sequences for initial HMM estimation
    # Make K subsets data of LENGTH
    for i in range(LENGTH):
        for j in range(K):
            if(i%K==j):
                X_i[j].append(list(X[i]))
                NUM_CLUSTER_PREV[i] = j
                
    for i in range(K):
        model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
        X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        model.fit(X_temp, lengths)
        HMM_array.append(model)
    
    likelihood_prev = likelihood_array(HMM_array,X_i)
    print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_prev)
    NUM_ITERATIONS+=1
    while (True):
        # Assign all sequences to HMM models

        print("************ Check likelihood of sequence in HMM  *********")
        NUM_CLUSTER_NOW = {}
        for idx,x in enumerate(X):
            sequence = convert_values_to_list(x)
            hmm_index = likelihood_sequence(sequence, HMM_array)
            X_i[hmm_index].append(list(x))
            NUM_CLUSTER_NOW[idx] = hmm_index
        print("************ Checking likelihood done  *********")

        # Re-estimate parameters for new HMMs
        print("************ Re-estimating HMM *********")
        HMM_array_prev = HMM_array
        HMM_array = []
        for i in range(K):
            model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
            if(len(X_i[i])>=model.n_components):
                X_temp, lengths = conversion_list_of_list(X_i[i], DIMENSION)
                model.fit(X_temp, lengths)
                HMM_array.append(model)
            else:
                HMM_array.append(HMM_array_prev[i])
        print("************ Re-estimation done *********")
        likelihood_curr = likelihood_array(HMM_array,X_i)
        print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_curr)
        print("*****************************************")

        # if no reassignments, then break
        if ((NUM_CLUSTER_PREV == NUM_CLUSTER_NOW) or NUM_ITERATIONS>40):
            HMM_K_ARRAYS.append(HMM_array)
            X_i_K_ARRAYS.append(X_i)
            break
        else:
            # initialize empty subsets of data for next iteration
            X_i = []
            for i in range(K):
                X_i.append([])

            NUM_CLUSTER_PREV = NUM_CLUSTER_NOW
            print("Num iterations is:", NUM_ITERATIONS)
            NUM_ITERATIONS += 1
            likelihood_prev = likelihood_curr
    print("**********************************************************\n\n")
# Out:
# **************** K = 2 ************************
# Likelihood for iteration 0 is 1683049.823
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 9186727.78589
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 2309348.96997
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 2245172.86961
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 2185340.99785
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 2079819.24714
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 1898593.5367
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 555981.927308
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 314868.85124
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 329652.27184
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 454717.705834
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 628032.531407
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 776014.986854
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 977956.289109
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 1115295.72612
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 1201794.37094
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 1313310.38518
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 1433835.3313
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 1521712.98485
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 1569031.69785
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 1638767.11996
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 1687136.15032
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 1746148.8566
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 1814052.37081
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 1854284.09394
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 1877760.43377
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 1909539.35266
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 1980715.15732
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 2013438.38278
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 2043702.88961
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 2095541.51281
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 2161624.68559
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 2215433.82671
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 2251948.87491
# *****************************************
# Num iterations is: 33
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 34 is 2293198.59793
# *****************************************
# Num iterations is: 34
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 35 is 2302571.88792
# *****************************************
# Num iterations is: 35
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 36 is 2325107.237
# *****************************************
# Num iterations is: 36
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 37 is 2361215.12856
# *****************************************
# Num iterations is: 37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 38 is 2386036.63267
# *****************************************
# Num iterations is: 38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 39 is 2414586.91376
# *****************************************
# Num iterations is: 39
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is 2426314.86243
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is 2430115.65511
# *****************************************
# **********************************************************
#
#
# **************** K = 3 ************************
# Likelihood for iteration 0 is 533042956.704
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 6940617928.59
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 1070184883.6
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 1131457689.18
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 1187500619.1
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 1225239340.2
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 1247213114.17
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 1263121935.54
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 1264408044.13
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 1275484629.77
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 1269746440.36
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 1263685876.29
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 1257639600.51
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 1258115778.49
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 1242762464.76
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 1229605016.77
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 1219592869.49
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 1200480972.24
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 1189914965.53
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 1182176734.22
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 1170899804.95
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 1146106952.21
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 1124279497.15
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 1123745710.42
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 1134350140.28
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 1141940570.25
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 1141038546.19
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 1135392345.12
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 1120249277.81
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 1114230029.72
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 1113192433.08
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 1112946674.94
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 1114928308.18
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 1114928308.41
# *****************************************
# **********************************************************
#
#
# **************** K = 4 ************************
# Likelihood for iteration 0 is 113498778911.0
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 3.20620286655e+12
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 39657994487.4
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 665387687.338
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -557465421.759
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -707788841.243
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -779850495.731
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -858191439.692
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -897048367.083
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -887272099.983
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -931290126.933
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -937366638.463
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -946505651.352
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -737147461.007
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 6440301320.26
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -602626209.198
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 121822559.242
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 123498661.105
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 124256942.769
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 125668095.162
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 126316783.917
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 127171423.606
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 127856648.697
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 128772711.141
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 130286250.22
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 132143060.694
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 132814766.74
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 132746736.552
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 133578832.872
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 134028666.989
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 135738006.807
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 138932518.796
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 141309966.277
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 143308067.67
# *****************************************
# Num iterations is: 33
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 34 is 146622644.767
# *****************************************
# Num iterations is: 34
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 35 is 148586125.931
# *****************************************
# Num iterations is: 35
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 36 is 152016096.037
# *****************************************
# Num iterations is: 36
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 37 is 1693699267.02
# *****************************************
# Num iterations is: 37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 38 is 3142057415.93
# *****************************************
# Num iterations is: 38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 39 is 3161713684.45
# *****************************************
# Num iterations is: 39
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 40 is 3243765471.25
# *****************************************
# Num iterations is: 40
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 41 is 3170625499.13
# *****************************************
# **********************************************************
#
#
# **************** K = 5 ************************
# Likelihood for iteration 0 is 1.7448306588e+13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 1.05558316285e+15
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 8.51319414518e+12
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 2.17624638293e+13
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 3.49359786435e+13
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 4.34541806175e+13
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 5.25195933683e+13
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 5.89928480034e+13
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 6.35172095208e+13
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 6.80317600082e+13
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 6.78920488366e+13
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 6.8570226246e+13
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 6.63672312464e+13
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 6.61209313262e+13
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 6.61209313262e+13
# *****************************************
# **********************************************************
#
#
# **************** K = 6 ************************
# Likelihood for iteration 0 is 2.22054781113e+15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 3.18384186249e+17
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 8.48947840536e+14
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 6.4092499643e+14
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 1.19935854916e+15
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 3.60563320849e+15
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 5.18851477578e+15
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 6.29343578786e+15
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 6.44788003433e+15
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 6.72530893677e+15
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 6.91863095985e+15
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 7.29818103451e+15
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 7.85440615093e+15
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 8.2840841288e+15
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 8.40860599875e+15
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 8.4634462025e+15
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 8.54280570032e+15
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 8.60986117495e+15
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 8.60989776562e+15
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 8.62878642141e+15
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 8.68425580113e+15
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 8.6532299838e+15
# *****************************************
# **********************************************************
#
#
# **************** K = 7 ************************
# Likelihood for iteration 0 is 2.23573118659e+17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 4.3367904692e+19
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 3.90026677746e+14
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 2.42626432007e+17
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 3.26507747194e+17
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 4.39722290364e+17
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 6.03632901361e+17
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# ...
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 2.0760584753e+32
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 2.44108310127e+32
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 2.44929932937e+32
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 2.43971459595e+32
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 2.4344379888e+32
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 2.42228999912e+32
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 2.39629867413e+32
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 2.40007005517e+32
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 2.47005217295e+32
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 2.18194314516e+33
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 3.97167077978e+33
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 6.99780864964e+33
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 8.11271471148e+33
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 8.92021574572e+33
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 1.49262621523e+34
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 3.02844730808e+33
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 1.13644041649e+34
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 1.3848120379e+34
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 1.485362687e+34
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 1.59262287081e+34
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 1.63919246708e+34
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 1.66709045141e+34
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 1.6671108571e+34
# *****************************************
# **********************************************************
#
#
# **************** K = 19 ************************
# Likelihood for iteration 0 is 1.54509220647e+37
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -3.27341649295e+42
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -2.59988139554e+23
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 1.38725455914e+27
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 1.60991535429e+31
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 5.63413219732e+31
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 3.54844137758e+32
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 1.43782381824e+33
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 2.32046567419e+33
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 2.84744938057e+33
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 3.35864365273e+33
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 3.73796016907e+33
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 3.84870107489e+33
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 3.84842565837e+33
# *****************************************
# **********************************************************
#
#
# **************** K = 20 ************************
# Likelihood for iteration 0 is 4.42998545989e+38
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 1.98017252796e+45
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 9.1155543166e+30
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 2.9711530403e+35
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 4.83109310161e+36
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 1.92523415496e+37
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 2.59798795899e+37
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 3.40026741404e+37
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is 3.89770333903e+37
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 4.18342374848e+37
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 4.42036934349e+37
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 4.60257148766e+37
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 4.78052153947e+37
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 5.41252567358e+37
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 5.42579124179e+37
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 5.46557429649e+37
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 5.46557429649e+37
# *****************************************
# **********************************************************

# %%
print(len(HMM_K_ARRAYS))
print(len(X_i_K_ARRAYS))
# Out:
# 19
# 19

# %%
dill.dump_session('../Weights/HMM_GaussianHMM_i_normalized.db')

# %% [markdown]
# # Calculate BIC for these assignments

# %%
print(BIC_array(HMM_array,X_i))

# %%
print(BIC_array(HMM_array,X_i))

# %% [markdown]
# # Noise Cluster

# %%
# Get list of lists to fit
Z, lengths = conversion_list_of_list(X,DIMENSION)

# %%
# Noise cluster 

model_noise = hmm.GMMHMM(n_components=3,n_mix=3,covariance_type='spherical')
model_noise.fit(Z, lengths)

# %%
HMM_model_stats(model_noise)

# %% [markdown]
# # Generate subsets of data for K HMMs

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))

# %%
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='full')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)

# %% [markdown]
# ## Statistics for K HMMs

# %%
HMM_model_stats(model)
print('\n\n')
model.predict([[7.56030946],[5.96591207],[6.40121497]],lengths=[3])
# Out:
# *************************************
# Transition matrix
# [[  9.99276869e-01   6.38482140e-04   8.46487741e-05]
#  [  1.93144205e-04   9.99806856e-01   2.07287602e-13]
#  [  1.68090394e-02   2.12582122e-11   9.83190961e-01]]
# *************************************
# Means and stds of each hidden state
# Hidden state 0
# mean =  [ 5.85591189]
# std =  [array([[ 0.49587845]])]
#
# Hidden state 1
# mean =  [ 7.75447354]
# std =  [array([[ 1.05975496]])]
#
# Hidden state 2
# mean =  [ 4.32879483]
# std =  [array([[ 0.68723547]])]
# array([1, 1, 1])

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='diag')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)
    HMM_array.append(model)
for i in range(K):
    print("Statistics for HMM Model", i)
    HMM_model_stats(HMM_array[i])
    print('\n\n')

# %%
NUM_ITERATIONS = 1
NUM_CLUSTER_PREV = {}
NUM_CLUSTER_NOW = {}

# %%
#initialize empty subsets of data
X_i = []

for i in range(K):
    X_i.append([])

# %%
likelihood_prev = likelihood_array(HMM_array,X_i)
print("Likelihood for iteration",0,"is",likelihood_prev)
