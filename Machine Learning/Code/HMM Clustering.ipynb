# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
from hmmlearn import hmm
import warnings
from constants import *
import math
import random
import matplotlib.pyplot as plt
import dill

# %% [markdown]
# # Helper Methods

# %%
def generate_random_sample(X, size):
    '''
    Given a list X, 
    generate random samples of given size
    '''
    Z_temp = random.sample(list(X), size)
    
    #Concatenation
    Z = [Z_temp[0]]
    for val in Z_temp[1:]:
        Z = np.concatenate([Z,[val]])
    
    return Z

def convert_values_to_list(list_val):
    '''
    Given a list X = [1 2 3] , 
    return X = [[1],[2],[3]]
    '''
    X = []
    for i in list_val:
        X.append([i])
    return X

def conversion_list_of_list(X, DIMENSION):
    '''
    Given a list X with values in lists,
    X = [[ 3  2  2],[4 8 10]]
    Convert each value to a list
    Return list of lists, array of lengths of each sequence
    X = [[3] [2] [2] [4] [8] [10]]
    ''' 
    X_new = []
    length = len(X)
    for idx, val_list in enumerate(X):
        Y = []
        for val in val_list:
            Y.append([val])
        X_new.append(Y)

    #Concatenation
    Z = X_new[0]
    for val_list in X_new[1:]:
        Z = np.concatenate([Z,val_list])

    # assign array of lengths for HMM
    lengths = [DIMENSION]*length
    
    return Z,lengths

#Calculate likelihood for given sequence according to given HMMs and return HMM
def likelihood_sequence(sequence, HMM_array):
    '''
    Given list of K HMMs and sequence,
    determines likelihood of sequence under all HMM models
    Returns index of HMM which has max likelihood
    ''' 
    scores = []
    length = [len(sequence)]
    for i, HMM in enumerate(HMM_array):
        calculated_score = HMM.score(sequence, length)
        scores.append(calculated_score)
    idx = scores.index(max(scores))
    return idx

def HMM_model_stats(model):
    '''
    Details of HMM model
    ''' 
    print("*************************************")
    print("Transition matrix")
    print(model.transmat_)
    print("*************************************")
    print("Means and stds of each hidden state")
    for i in range(model.n_components):
        print("Hidden state {0}".format(i))
        print("mean = ", model.means_[i])
        print("std = ", [np.sqrt(model.covars_[i])])
        print()

def BIC(model,X,lengths):
    LogLikelihood = model.score(X,lengths)
    num_hidden_states = model.n_components
    # D counts transition matrix (emission estimated by PDF), means = num_hidden_states  
    # covariance matrix = num_hidden_states
    D = num_hidden_states**2 + 2*num_hidden_states
    BIC = LogLikelihood - (D/2)*np.log(len(X))
    return BIC
    
def BIC_array(HMM_array,X_i):
    BIC_total = 0
    for i in range(len(X_i)):
        model = HMM_array[i]
        X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        BIC_total+= BIC(model,X,lengths)
    return BIC_total

def likelihood_array(HMM_array,X_i):
    likelihood_total = 1
    for i in range(len(X_i)):
        if(len(X_i[i])>=HMM_array[i].n_components):
            model = HMM_array[i]
            X, lengths = conversion_list_of_list(X_i[i],DIMENSION)
            LogLikelihood = model.score(X,lengths)
            likelihood = LogLikelihood 
            likelihood_total*= likelihood
    return likelihood_total

def plot_BIC(list_k, BIC_score):
    fig = plt.subplot(111)
    plt.plot(list_k, BIC_score, marker='o')  
    plt.xlabel('Value of K')
    plt.ylabel('Objective')
    plt.title('BIC')
    plt.show() 

def print_stats(assignments,length):
    for i in range(length):
        if(i%100==0):
            print(assignments[i])

# %% [markdown]
# # Load Data and Clean

# %%
df = pd.read_csv('../Data/merged.txt', sep=",", na_values=['-'])
df = df.dropna()
df = df[['cdReads0','cdReads1','cdReads2','cdRPKM0','cdRPKM1','cdRPKM2']]

# %% [markdown]
# # Filter cdReads

# %%
df = df[(df['cdReads0'] >= 50) & (df['cdReads1'] >= 50) & (df['cdReads2'] >= 50)]

# %%
#Dataset
df_main = df[['cdRPKM0','cdRPKM1','cdRPKM2']]
LENGTH,DIMENSION = df_main.shape
print("Dataset size is",LENGTH)
print("Features are", DIMENSION)
print(df_main.head(5))
X = np.log2(df_main.values)
print("****************************")
print("First 5 log2 values\n",X[:5])
# Out:
# Dataset size is 2072
# Features are 3
#        cdRPKM0     cdRPKM1     cdRPKM2
# 6    39.456786   62.505536   84.519655
# 19   29.836928   22.172994   17.721150
# 34  188.746942  211.104962  221.175677
# 57  283.823604  374.683044  285.247754
# 81   90.967704  125.648541  120.892583
# ****************************
# First 5 log2 values
#  [[ 5.30220154  5.96591207  6.40121497]
#  [ 4.89902709  4.47073168  4.14740034]
#  [ 7.56030946  7.72181668  7.78904893]
#  [ 8.14885076  8.54952688  8.15607171]
#  [ 6.50728253  6.97325011  6.91758192]]

# %% [markdown]
# # Arrays with HMM models for 1<=K<=25

# %%
HMM_K_ARRAYS = []
X_i_K_ARRAYS = []

# %% [markdown]
# # Check likelihood and do assignments

# %%
K_values = range(28,31)

# %%
for K in K_values:
    HMM_array = []
    X_i = []
    print("**************** K =", K ,"************************")
    for i in range(K):
        X_i.append([])
        
    NUM_ITERATIONS = 0
    NUM_CLUSTER_PREV = {}
    NUM_CLUSTER_NOW = {}
    
    # Sequences for initial HMM estimation
    # Make K subsets data of LENGTH
    for i in range(LENGTH):
        for j in range(K):
            if(i%K==j):
                X_i[j].append(list(X[i]))
                NUM_CLUSTER_PREV[i] = j
                
    for i in range(K):
        model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
        X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
        model.fit(X_temp, lengths)
        HMM_array.append(model)
    
    likelihood_prev = likelihood_array(HMM_array,X_i)
    print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_prev)
    NUM_ITERATIONS+=1
    while (True):
        # Assign all sequences to HMM models

        print("************ Check likelihood of sequence in HMM  *********")
        NUM_CLUSTER_NOW = {}
        for idx,x in enumerate(X):
            sequence = convert_values_to_list(x)
            hmm_index = likelihood_sequence(sequence, HMM_array)
            X_i[hmm_index].append(list(x))
            NUM_CLUSTER_NOW[idx] = hmm_index
        print("************ Checking likelihood done  *********")

        # Re-estimate parameters for new HMMs
        print("************ Re-estimating HMM *********")
        HMM_array_prev = HMM_array
        HMM_array = []
        for i in range(K):
            model = hmm.GaussianHMM(n_components=3,covariance_type='diag')
            if(len(X_i[i])>=model.n_components):
                X_temp, lengths = conversion_list_of_list(X_i[i], DIMENSION)
                model.fit(X_temp, lengths)
                HMM_array.append(model)
            else:
                HMM_array.append(HMM_array_prev[i])
        print("************ Re-estimation done *********")
        likelihood_curr = likelihood_array(HMM_array,X_i)
        print("Likelihood for iteration",NUM_ITERATIONS,"is",likelihood_curr)
        print("*****************************************")

        # if no reassignments, then break
        if ((NUM_CLUSTER_PREV == NUM_CLUSTER_NOW) or NUM_ITERATIONS>40):
            HMM_K_ARRAYS.append(HMM_array)
            X_i_K_ARRAYS.append(X_i)
            break
        else:
            # initialize empty subsets of data for next iteration
            X_i = []
            for i in range(K):
                X_i.append([])

            NUM_CLUSTER_PREV = NUM_CLUSTER_NOW
            print("Num iterations is:", NUM_ITERATIONS)
            NUM_ITERATIONS += 1
            likelihood_prev = likelihood_curr
    print("**********************************************************\n\n")
# Out:
# **************** K = 28 ************************
# Likelihood for iteration 0 is 5.45803040423e+68
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 1.57578441927e+72
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is -7.32688542047e+30
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -6.31314845608e+37
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is -9.5637161664e+37
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is 2.48538986749e+42
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 6.17261828284e+43
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 1.42145260579e+44
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -3.12830216381e+44
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is 8.09226607581e+44
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is 9.0092800399e+45
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is 1.61853299845e+46
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is 2.47399105105e+46
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is 3.85162877649e+46
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is 4.89372800378e+46
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 5.2708190946e+46
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 5.44109210147e+46
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 5.88666242472e+46
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 6.27766077207e+46
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 6.02567275675e+46
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 6.00342414476e+46
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 6.00873573024e+46
# *****************************************
# **********************************************************
#
#
# **************** K = 29 ************************
# Likelihood for iteration 0 is -4.33850901175e+70
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is -3.20398252649e+74
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 2.66565680135e+34
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is -8.90452836909e+37
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 3.11069474477e+40
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -5.56089180418e+40
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is 1.39578794186e+41
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is 4.39008442712e+42
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -5.06870916666e+41
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -2.19695811914e+42
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -3.32518331643e+44
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -1.72589287907e+44
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -1.59929221506e+44
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -1.01087351482e+44
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -3.46578067451e+43
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is -1.02744162137e+44
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is -1.14789453694e+44
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is -1.42902210714e+44
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is -2.47113414423e+44
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is -2.50653836975e+44
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is -2.5126856063e+44
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is -2.54135164063e+44
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is -2.57447297356e+44
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is -2.56259710869e+44
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is -2.5688788297e+44
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is -2.75943142481e+44
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is -4.303626966e+44
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is -5.24979889185e+44
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is -6.31175948833e+44
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is -7.98617615717e+44
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is -7.16193634632e+44
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is -7.49252015692e+44
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is -7.46037545399e+44
# *****************************************
# **********************************************************
#
#
# **************** K = 30 ************************
# Likelihood for iteration 0 is 6.51770683005e+72
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 1 is 2.97857249231e+76
# *****************************************
# Num iterations is: 1
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 2 is 7.27659279772e+33
# *****************************************
# Num iterations is: 2
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 3 is 2.38085847745e+43
# *****************************************
# Num iterations is: 3
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 4 is 1.25151482152e+44
# *****************************************
# Num iterations is: 4
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 5 is -1.72083994514e+46
# *****************************************
# Num iterations is: 5
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 6 is -1.54580915221e+47
# *****************************************
# Num iterations is: 6
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 7 is -5.0721338414e+47
# *****************************************
# Num iterations is: 7
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 8 is -2.1633024045e+48
# *****************************************
# Num iterations is: 8
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 9 is -6.04126828109e+48
# *****************************************
# Num iterations is: 9
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 10 is -6.67008290096e+48
# *****************************************
# Num iterations is: 10
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 11 is -5.32510055411e+48
# *****************************************
# Num iterations is: 11
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 12 is -7.55409637486e+47
# *****************************************
# Num iterations is: 12
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 13 is -2.98246739913e+47
# *****************************************
# Num iterations is: 13
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 14 is -4.5933626074e+47
# *****************************************
# Num iterations is: 14
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 15 is 2.43479299675e+46
# *****************************************
# Num iterations is: 15
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 16 is 2.39752049384e+46
# *****************************************
# Num iterations is: 16
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 17 is 6.27719474621e+48
# *****************************************
# Num iterations is: 17
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 18 is 6.12339587862e+48
# *****************************************
# Num iterations is: 18
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 19 is 7.83262585195e+48
# *****************************************
# Num iterations is: 19
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 20 is 8.2195293565e+48
# *****************************************
# Num iterations is: 20
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 21 is 7.41540482954e+48
# *****************************************
# Num iterations is: 21
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 22 is 7.07556437776e+48
# *****************************************
# Num iterations is: 22
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 23 is 9.17216415941e+48
# *****************************************
# Num iterations is: 23
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 24 is 1.54766184509e+49
# *****************************************
# Num iterations is: 24
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 25 is 3.20502203613e+49
# *****************************************
# Num iterations is: 25
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 26 is 2.31924992493e+49
# *****************************************
# Num iterations is: 26
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 27 is 2.47852156883e+49
# *****************************************
# Num iterations is: 27
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 28 is 3.04258625642e+49
# *****************************************
# Num iterations is: 28
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 29 is 4.36626351977e+49
# *****************************************
# Num iterations is: 29
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 30 is 5.17774949979e+49
# *****************************************
# Num iterations is: 30
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 31 is 5.38312840475e+49
# *****************************************
# Num iterations is: 31
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 32 is 5.34385820821e+49
# *****************************************
# Num iterations is: 32
# ************ Check likelihood of sequence in HMM  *********
# ************ Checking likelihood done  *********
# ************ Re-estimating HMM *********
# ************ Re-estimation done *********
# Likelihood for iteration 33 is 5.3358953386e+49
# *****************************************
# **********************************************************

# %%
print(len(HMM_K_ARRAYS))
print(len(X_i_K_ARRAYS))
# Out:
# 29
# 29

# %%
dill.dump_session('../Weights/HMM_GaussianHMM_i.db')

# %% [markdown]
# # Calculate BIC for these assignments

# %%
print(BIC_array(HMM_array,X_i))

# %%
print(BIC_array(HMM_array,X_i))

# %% [markdown]
# # Noise Cluster

# %%
# Get list of lists to fit
Z, lengths = conversion_list_of_list(X,DIMENSION)

# %%
# Noise cluster 

model_noise = hmm.GMMHMM(n_components=3,n_mix=3,covariance_type='spherical')
model_noise.fit(Z, lengths)

# %%
HMM_model_stats(model_noise)

# %% [markdown]
# # Generate subsets of data for K HMMs

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))

# %%
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='full')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)

# %% [markdown]
# ## Statistics for K HMMs

# %%
HMM_model_stats(model)
print('\n\n')
model.predict([[7.56030946],[5.96591207],[6.40121497]],lengths=[3])
# Out:
# *************************************
# Transition matrix
# [[  9.99276869e-01   6.38482140e-04   8.46487741e-05]
#  [  1.93144205e-04   9.99806856e-01   2.07287602e-13]
#  [  1.68090394e-02   2.12582122e-11   9.83190961e-01]]
# *************************************
# Means and stds of each hidden state
# Hidden state 0
# mean =  [ 5.85591189]
# std =  [array([[ 0.49587845]])]
#
# Hidden state 1
# mean =  [ 7.75447354]
# std =  [array([[ 1.05975496]])]
#
# Hidden state 2
# mean =  [ 4.32879483]
# std =  [array([[ 0.68723547]])]
# array([1, 1, 1])

# %%
K = 3
HMM_array = []
X_i = []

for i in range(K):
    X_i.append([])

# Sequences for initial HMM estimation
for i in range(LENGTH):
    for j in range(K):
        if(i%K==j):
            X_i[j].append(list(X[i]))
for i in range(K):
    model = hmm.GaussianHMM(n_components=3, covariance_type='diag')
    X_temp, lengths = conversion_list_of_list(X_i[i],DIMENSION)
    model.fit(X_temp, lengths)
    HMM_array.append(model)
for i in range(K):
    print("Statistics for HMM Model", i)
    HMM_model_stats(HMM_array[i])
    print('\n\n')

# %%
NUM_ITERATIONS = 1
NUM_CLUSTER_PREV = {}
NUM_CLUSTER_NOW = {}

# %%
#initialize empty subsets of data
X_i = []

for i in range(K):
    X_i.append([])

# %%
likelihood_prev = likelihood_array(HMM_array,X_i)
print("Likelihood for iteration",0,"is",likelihood_prev)
